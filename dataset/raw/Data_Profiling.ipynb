# %%
import pandas as pd
import os

folder = r"C:\Users\himni\Downloads\synthea_sample_data_csv_nov2021\csv"

for file in os.listdir(folder):

    if file.endswith(".csv"):

        path = os.path.join(folder,file)

        df = pd.read_csv(path)

        print("="*80)
        print(file)
        print("="*80)

        print("Rows:",len(df))
        print("Columns:",len(df.columns))

        print(df.dtypes)

        print("\n")
# Out:
# ...
# allergies.csv
# ...
# Rows: 794
# Columns: 15
# START            object
# STOP            float64
# PATIENT          object
# ENCOUNTER        object
# CODE              int64
# SYSTEM           object
# DESCRIPTION      object
# TYPE             object
# CATEGORY         object
# REACTION1       float64
# DESCRIPTION1     object
# SEVERITY1        object
# REACTION2       float64
# DESCRIPTION2     object
# SEVERITY2        object
# dtype: object
#
#
# ...
# careplans.csv
# ...
# Rows: 3931
# Columns: 9
# Id                    object
# START                 object
# STOP                  object
# PATIENT               object
# ENCOUNTER             object
# CODE                   int64
# DESCRIPTION           object
# REASONCODE           float64
# REASONDESCRIPTION     object
# dtype: object
#
#
# ...
# claims.csv
# ...
# Rows: 117889
# Columns: 31
# Id                              object
# PATIENTID                       object
# PROVIDERID                      object
# PRIMARYPATIENTINSURANCEID       object
# ...

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\himni\Downloads\synthea_sample_data_csv_nov2021\csv\providers.csv")

print(df.columns.tolist())
# Out:
# ['Id', 'ORGANIZATION', 'NAME', 'GENDER', 'SPECIALITY', 'ADDRESS', 'CITY', 'STATE', 'ZIP', 'LAT', 'LON', 'UTILIZATION']
